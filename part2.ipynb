# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gensim in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 1)) (4.3.3)
# Requirement already satisfied: pandas in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 3)) (3.9.4)
# Requirement already satisfied: nltk in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 4)) (3.9.1)
# Requirement already satisfied: notebook in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 5)) (7.3.3)
# Requirement already satisfied: numpy in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: seaborn in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from -r requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from gensim->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from gensim->-r requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (6.5.2)
# Requirement already satisfied: click in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nltk->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: joblib in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nltk->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nltk->-r requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nltk->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from notebook->-r requirements.txt (line 5)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from notebook->-r requirements.txt (line 5)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.6 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from notebook->-r requirements.txt (line 5)) (4.3.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from notebook->-r requirements.txt (line 5)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from notebook->-r requirements.txt (line 5)) (6.4.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 3)) (3.21.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (26.3.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (8.6.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (75.8.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: babel>=2.10 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: wrapt in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from smart-open>=1.8.1->gensim->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: colorama in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from click->nltk->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (4.13.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: certifi in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (7.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (310)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.19.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: webencodings in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: decorator in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (3.0.50)
# Requirement already satisfied: stack-data in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: fqdn in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.6)
# Requirement already satisfied: pycparser in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\willi\anaconda3\envs\dsad\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.9.0.20241206)

# %%
# standard library imports
import json
import re

# third party imports
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\willi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\willi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Using df = pd.read_json("./data/careerbuilder_usa.ldjson", lines=True, orient='records') did not work due to missing newline characters
# Hence, I used the following approach
jsonls = []
with open('./data/careerbuilder_usa.ldjson', 'r') as f:
    jsonls = []
    for i, line in enumerate(f):
        l = line.replace('}{"', '}\n{"')
        for newline in l.split('\n')[:-1]:
            jsonls.append(json.loads(newline))

df_raw = pd.DataFrame(jsonls)

# %%
df_raw.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'url', 'job_title', 'company_name',
#        'city', 'state', 'country', 'post_date', 'job_description', 'job_type',
#        'inferred_salary_time_unit', 'company_description', 'salary_offered',
#        'job_board', 'geo', 'job_post_lang', 'valid_through',
#        'html_job_description', 'inferred_iso2_lang_code',
#        'inferred_iso3_lang_code', 'site_name', 'domain', 'postdate_yyyymmdd',
#        'has_expired', 'last_expiry_check_date', 'latest_expiry_check_date',
#        'duplicate_status', 'postdate_in_indexname_format', 'inferred_city',
#        'inferred_state', 'inferred_country', 'fitness_score',
#        'inferred_salary_from', 'inferred_salary_to',
#        'inferred_salary_currency', 'is_consumed_job', 'job_requirements',
#        'contact_email', 'test_contact_email'],
#       dtype='object')

# %%
# Focus on columns that may be useful for uncovering skills trends in data science
df = df_raw[['job_title', 'job_description', 'company_description', 'job_requirements']]
display(df.head())

# Replace empty company description with null value, then drop columns with >80% null values
df.loc[:,'company_description'] = df['company_description'].replace('', None)
df = df.dropna(thresh=int(0.8*df.shape[0]), axis=1)
print("After dropping null/empty values:")
df.head()
# Out:
#                                            job_title  ... job_requirements
# 0            Asphalt/Concrete Senior Project Manager  ...              NaN
# 1                  Amazon Warehouse Team - Full Time  ...              NaN
# 2  Amazon Warehouse Associate - Morning Shifts Av...  ...              NaN
# 3                                Assembly Electrical  ...              NaN
# 4                                  Graphics Designer  ...              NaN
#
# [5 rows x 4 columns]
# After dropping null/empty values:
#                                            job_title                                    job_description
# 0            Asphalt/Concrete Senior Project Manager  SR. PROJECT MANAGER WANTED!!! My client is a M...
# 1                  Amazon Warehouse Team - Full Time  Shifts: Overnight, Early Morning, Day, Evening...
# 2  Amazon Warehouse Associate - Morning Shifts Av...  Shifts: Early Morning, Day, Evening Location: ...
# 3                                Assembly Electrical  Do you pride yourself on attention to detail a...
# 4                                  Graphics Designer  In your role as Graphics Designer for Alaska C...

# %%
has_data = df['job_title'].str.lower().str.contains('data')
not_data_management = ~df['job_title'].str.lower().str.contains('data entr') \
    & ~df['job_title'].str.lower().str.contains('engin') \
    & ~df['job_title'].str.lower().str.contains('archi') \
    & ~df['job_title'].str.lower().str.contains('admin')
subset_df = df[(has_data & not_data_management)]

# %%
subset_df
# Out:
#                                                job_title                                    job_description
# 439                                         Data Analyst  Ref ID: 01030 [ Phone number blocked ] Classif...
# 740         Lead Azure Data Factory/Logic Apps Developer  Lead Azure Data Factory/Logic Apps Developer P...
# 865                                   Database Developer  Ref ID: 02910-0011489692 Classification: Datab...
# 1578                           Data Analyst - Point Mugu  JT4 provides engineering and technical support...
# 1744                           Big Data Business Analyst  Important Note: During the application process...
# ...                                                  ...                                                ...
# 28445                                       Data Analyst  Ref ID: 02380 [ Phone number blocked ] Classif...
# 28648          Buyside - Data Scientist/Research Analyst  We're currently working closely with a prestig...
# 28654  Business Initiatives Consultant 3 / Data Initi...  Important Note: During the application process...
# 28882                                  Data Team Manager  JOB OVERVIEW: Capital Insurance Group is seeki...
# 29525                           Principal Data Scientist  Company Overview:Charter Communications is Ame...
#
# [124 rows x 2 columns]

# %%
standardisation_dict = {
    "natural language processing": "nlp",
    "machine learning": "ml",
    "artificial intelligence": "ai",
    "google cloud platform": "gcp",
    "google cloud": "gcp",
    "amazon web services": "aws",
    "microsoft azure": "azure",
    "big data": "big_data"
}
def clean_text(text):
    text = text.lower()
    #remove punctuations
    text = re.sub(r'[,\.!?":\[\]\(\)-;•\*\$]', '', text)
    #remove numbers
    text = re.sub(r'\d+', ' ', text)
    for key, value in standardisation_dict.items():
        text = text.replace(key, value)
    return text

# %%
subset_df['cleaned_jd'] = subset_df['job_description'].apply(clean_text)
subset_df
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_18768\3152974681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['cleaned_jd'] = subset_df['job_description'].apply(clean_text)
#                                                job_title  ...                                             tokens
# 439                                         Data Analyst  ...  [ref, id, phone, number, blocked, classificati...
# 740         Lead Azure Data Factory/Logic Apps Developer  ...  [lead, azure, data, factory, logic, apps, deve...
# 865                                   Database Developer  ...  [ref, id, classification, database, developer,...
# 1578                           Data Analyst - Point Mugu  ...  [jt, provides, engineering, technical, support...
# 1744                           Big Data Business Analyst  ...  [important, note, application, process, ensure...
# ...                                                  ...  ...                                                ...
# 28445                                       Data Analyst  ...  [ref, id, phone, number, blocked, classificati...
# 28648          Buyside - Data Scientist/Research Analyst  ...  [currently, working, closely, prestigious, inv...
# 28654  Business Initiatives Consultant 3 / Data Initi...  ...  [important, note, application, process, ensure...
# 28882                                  Data Team Manager  ...  [job, overview, capital, insurance, group, see...
# 29525                           Principal Data Scientist  ...  [company, overviewcharter, communications, ame...
#
# [124 rows x 4 columns]

# %%
stop_words = stopwords.words('english') + ["n't", "job", "requirements", "experience", "skills", "years", "required", "must", "&", "'", "please", "careerbuilder", "work", "fargo"]
vectorizer = CountVectorizer(tokenizer=word_tokenize, stop_words=stop_words, max_features=5000)
lda = LatentDirichletAllocation(n_components=10, random_state=42)
lda.fit(vectorizer.fit_transform(subset_df['cleaned_jd']))
# Out:
# LatentDirichletAllocation(random_state=42)

# %%
vocab = vectorizer.get_feature_names_out()
def get_top_words(model, feature_names, n_words=10):
    topics = []
    for comp in model.components_:
        word_idx = comp.argsort()[::-1][:n_words]
        top_words = [feature_names[i] for i in word_idx]
        topics.append(top_words)
    return topics

topics = get_top_words(lda, vocab, n_words=10)
for idx, words in enumerate(topics):
    print(f"Topic {idx}: {', '.join(words)}")
# Out:
# Topic 0: sql, data, server, knowledge, database, transplant, r, services, processes, etl
# Topic 1: data, database, business, management, ability, development, may, modeling, andor, link
# Topic 2: data, global, team, independently, use, operations, stakeholders, intelligence, ability, investment
# Topic 3: ml, learning, models, deep, teaching, engineering, bcforward, ai, ’, analytics
# Topic 4: facility, maintain, data, module, management, dmlssfm, support, maintenance, dmlss, facilities
# Topic 5: data, business, team, management, ability, solutions, systems, analysis, support, technical
# Topic 6: data, link, removed, technology, half, process, us, software, robert, research
# Topic 7: data, wells, business, management, team, customers, st, information, analysis, financial
# Topic 8: insurance, general, national, team, data, development, individuals, essential, status, protected
# Topic 9: data, information, security, provide, applying, apply, report, database, use, team
